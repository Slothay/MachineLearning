# %%
import numpy as np
import matplotlib.pyplot as plt



years = list(range(1920,2000))
growth = [0.20, 0.30, 0.42, 0.50, 0.60,
          0.75, 0.80, 0.85, 0.93, 1.02,
          1.07, 1.15, 1.21, 1.27, 1.32,
          1.37, 1.42, 1.46, 1.48, 1.52,
          1.53, 1.54, 1.55, 1.57, 1.58,
          1.59, 1.60, 1.61, 1.61, 1.61,
          1.60, 1.60, 1.59, 1.60, 1.60,
          1.60, 1.61, 1.60, 1.60, 1.60,
          1.60, 1.59, 1.58, 1.59, 1.59,
          1.60, 1.61, 1.62, 1.63, 1.64,
          1.65, 1.67, 1.68, 1.70, 1.71,
          1.71, 1.72, 1.74, 1.78, 1.82, 
          1.85, 1.88, 1.90, 2.00, 2.05,
          2.10, 2.15, 2.22, 2.28, 2.35,
          2.37, 2.40, 2.50, 2.60, 2.72,
          2.80, 2.90, 3.00, 3.10, 3.20  
          ]


          
          
X = np.array(years).reshape(-1,1)
y = np.array(growth).reshape(-1,1)
# Out:
# (array([[1920],
#         [1921],
#         [1922],
#         [1923],
#         [1924],
#         [1925],
#         [1926],
#         [1927],
#         [1928],
#         [1929],
#         [1930],
#         [1931],
#         [1932],
#         [1933],
#         [1934],
#         [1935],
#         [1936],
#         [1937],
#         [1938],
#         [1939],
#         [1940],
#         [1941],
#         [1942],
#         [1943],
#         [1944],
#         [1945],
#         [1946],
#         [1947],
#         [1948],
#         [1949],
#         [1950],
#         [1951],
#         [1952],
#         [1953],
#         [1954],
#         [1955],
#         [1956],
#         [1957],
#         [1958],
#         [1959],
#         [1960],
#         [1961],
#         [1962],
#         [1963],
#         [1964],
#         [1965],
#         [1966],
#         [1967],
#         [1968],
#         [1969],
#         [1970],
#         [1971],
#         [1972],
#         [1973],
#         [1974],
# ...

# %%
# Visualize the synthetic data
plt.scatter(X, y, label='Data Points')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Inverted Polynomial Regression Data')
plt.show()

# Perform polynomial regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

degree = 3  # Degree of the polynomial
polyreg = make_pipeline(PolynomialFeatures(degree), LinearRegression())
polyreg.fit(X, y)

# Generate predictions with the fitted model (tree - growth)
X_new = np.linspace(1920, 2000, 100).reshape(-1, 1)
y_pred = polyreg.predict(X_new)

# Generate predictions with the fitted model (girl - growth)
# X_new = np.linspace(5, 18, 100).reshape(-1, 1)
# y_pred = polyreg.predict(X_new)

# Visualize the regression line
plt.scatter(X, y, label='Data Points')
plt.plot(X_new, y_pred, color='red', label='Polynomial Regression')
plt.plot(X_new, y_pred + 1.0)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Inverted Polynomial Regression Fit')
plt.legend()
plt.show()

# %%
# 27 ages
ages = [5.0, 5.5, 6.0, 6.5, 7.0, 7.5,
        8.0, 8.5, 9.0, 9.5, 10.0,10.5,
        11.0,11.5,12.0,12.5,13.0,13.5,
        14.0,14.5,15.0,15.5,16.0,16.5,
        17.0,17.5, 18.0]

heights = [110.0, 115.0, 118.0, 121.5, 124.0, 127.0,
           129.5, 132.0, 135.0, 137.0, 142.0, 145.0,
           147.5, 150.0, 154.0, 157.5, 159.5, 161.5,
           163.0, 164.5, 165.7, 165.9, 166.2, 166.6,
           167.0, 167.4, 167.8]

X = np.array(ages).reshape(-1,1)
y = np.array(heights).reshape(-1,1)

# %%
# Visualize the synthetic data
plt.scatter(X, y, label='Data Points')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Inverted Polynomial Regression Data')
plt.show()

# Perform polynomial regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline

degree = 3  # Degree of the polynomial
polyreg = make_pipeline(PolynomialFeatures(degree), LinearRegression())
polyreg.fit(X, y)

# Generate predictions with the fitted model (tree - growth)
# X_new = np.linspace(1920, 2000, 100).reshape(-1, 1)
# y_pred = polyreg.predict(X_new)

# Generate predictions with the fitted model (girl - growth)
X_new = np.linspace(5, 18, 100).reshape(-1, 1)
y_pred = polyreg.predict(X_new)

# Visualize the regression line
plt.scatter(X, y, label='Data Points')
plt.plot(X_new, y_pred, color='red', label='Polynomial Regression')
plt.plot(X_new, y_pred + 1.0)
plt.xlabel('X')
plt.ylabel('y')
plt.title('Inverted Polynomial Regression Fit')
plt.legend()
plt.show()
