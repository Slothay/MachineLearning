# %% [markdown]
# # Standard deviation and Variance
# Standard deviation is a number that describes how spread out the values are.
#
# A low standard deviation means that most of the numbers are close to the mean (average) value.
#
# A high standard deviation means that the values are spread out over a wider range.

# %%
import numpy as np

speed = [86,87,88,86,87,85,86]

x = np.std(speed)
print('Standard deviation: ',  x)
# Out:
# Standard deviation:  0.9035079029052513

# %%
speed = [32,111,138,28,59,77,97]

y = np.std(speed)

print('Standard deviation: ',  y)
# Out:
# Standard deviation:  37.84501153334721

# %% [markdown]
# ## Variance
#
# Variance is another number that indicates how spread out the values are.
#
# In fact, if you take the square root of the variance, you get the standard deviation!
#
# Or the other way around, if you multiply the standard deviation by itself, you get the variance!
#
# To calculate the variance you have to do as follows:
#
# 1. Find the mean:
# 2. For each value: find the difference from the mean:
# 3. For each difference: find the square value:
# 4. The variance is the average number of these squared differences:

# %%
speed = [32,111,138,28,59,77,97]

x = np.var(speed)

print(x)
# Out:
# 1432.2448979591834

# %% [markdown]
# ## Standard Deviation
# As we have learned, the formula to find the standard deviation is the square root of the variance:

# %%
speed = [32,111,138,28,59,77,97]

x = np.std(speed)
y = np.var(speed)
z = np.sqrt(y)

print(f'Standard deviation {x}, Variance {y} and \nStandard deviation from variance {z} ')
# Out:
# Standard deviation 37.84501153334721, Variance 1432.2448979591834 and
# Standard deviation from variance 37.84501153334721

# %%
speed = [32,111,138,28,59,77,97]

mean_spead = np.mean(speed)

sum = 0
for value in speed:
   sum= sum + value 
mean_manual = sum/len(speed)

print(f'Mean speed {mean_spead} and Mean speed manual {mean_manual}')

print(np.std(speed))
# Out:
# Mean speed 77.42857142857143 and Mean speed manual 77.42857142857143
# 37.84501153334721

# %% [markdown]
# To calculate the variance you have to do as follows:
#
# 1. Find the mean:
# 2. For each value: find the difference from the mean:
# 3. For each difference: find the square value:
# 4. The variance is the average number of these squared differences:

# %%
sum_of_squares = 0
for value in speed:
    distance_to_mean = value - mean_manual
    squared_distance = distance_to_mean*distance_to_mean
    sum_of_squares += squared_distance

manual_variance = sum_of_squares/len(speed)
print(f'The variance calculated manually is: {manual_variance}, while Numpy gives: {np.var(speed)}')
print(f'The standard deviation is the square root of the variance: {np.sqrt(manual_variance)}')
# Out:
# The variance calculated manually is: 1432.2448979591834, while Numpy gives: 1432.2448979591834
# The standard deviation is the square root of the variance: 37.84501153334721

# %% [markdown]
# # Random numbers

# %% [markdown]
# Let us create two arrays that are both filled with 1000 random numbers from a normal data distribution.
#
# The first array will have the mean set to 5.0 with a standard deviation of 1.0.
#
# The second array will have the mean set to 10.0 with a standard deviation of 2.0:

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.random.normal(5, 2, 1000)
y = np.random.normal(5, 2, 1000)

plt.scatter(x, y)
plt.show()
