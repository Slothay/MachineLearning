# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Police set but without guard rails

# %%
result = pd.read_csv(r'D:\repos\dataengineering\yg821jf8611_il_statewide_2020_04_01.csv\il_statewide_2020_04_01.csv', index_col=0)
# Out:
# C:\Users\bjorn.bergdahl\AppData\Local\Temp\ipykernel_25664\659952621.py:1: DtypeWarning: Columns (3,4,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   result = pd.read_csv(r'D:\repos\dataengineering\yg821jf8611_il_statewide_2020_04_01.csv\il_statewide_2020_04_01.csv', index_col=0)

# %%
result.size
result.shape

result.sample(10)
# Out:
#                       date      time location  beat  subject_age subject_race  \
# raw_row_number
# 11016035        2017-12-07  18:25:00    60619   813          NaN        black
# 12567574        2017-01-15  13:21:00  62226.0   NaN          NaN        white
# 6278194         2015-02-21  19:54:00    50112     1          NaN        white
# 3034359         2013-11-26  09:17:00    33549    13          NaN        white
# 10102539        2016-02-28  17:33:00    60496  0201          NaN        black
# 9560870         2016-12-30  22:06:00    60435    12          NaN     hispanic
# 3268663         2013-01-03  10:02:00    60431  WCOV          NaN        white
# 12449849        2017-04-19  14:13:00    60118     4          NaN        white
# 5363811         2014-01-11  19:22:00    60436  S15M          NaN        black
# 7223617         2015-11-22  00:09:00    62269    11          NaN        white
#
#                subject_sex  department_id        department_name       type  \
# raw_row_number
# ...

# %%
result.columns
# Out:
# Index(['date', 'time', 'location', 'beat', 'subject_age', 'subject_race',
#        'subject_sex', 'department_id', 'department_name', 'type', 'violation',
#        'citation_issued', 'warning_issued', 'outcome', 'contraband_found',
#        'contraband_drugs', 'contraband_weapons', 'search_conducted',
#        'search_person', 'search_vehicle', 'search_basis', 'reason_for_stop',
#        'vehicle_make', 'vehicle_year', 'raw_DriverRace', 'raw_ReasonForStop',
#        'raw_TypeOfMovingViolation', 'raw_ResultOfStop'],
#       dtype='object')

# %%
result.head()
# Out:
#                       date      time location  beat  subject_age subject_race  \
# raw_row_number
# 1               2012-09-15  10:20:00    60641  1611          NaN     hispanic
# 2               2012-09-15  10:20:00    60189  1912          NaN        white
# 3               2012-09-15  10:20:00    60638   815          NaN     hispanic
# 4               2012-09-15  10:20:00    60638   925          NaN        white
# 5               2012-09-15  10:21:00      NaN  2032          NaN        black
#
#                subject_sex  department_id department_name       type  ...  \
# raw_row_number                                                        ...
# 1                     male        13194.0  CHICAGO POLICE  vehicular  ...
# 2                   female        13194.0  CHICAGO POLICE  vehicular  ...
# 3                   female        13194.0  CHICAGO POLICE  vehicular  ...
# 4                     male        13194.0  CHICAGO POLICE  vehicular  ...
# ...

# %%
result.dtypes
# Out:
# date                          object
# time                          object
# location                      object
# beat                          object
# subject_age                  float64
# subject_race                  object
# subject_sex                   object
# department_id                float64
# department_name               object
# type                          object
# violation                     object
# citation_issued                 bool
# warning_issued                  bool
# outcome                       object
# contraband_found              object
# contraband_drugs              object
# contraband_weapons            object
# search_conducted              object
# search_person                 object
# search_vehicle                object
# search_basis                  object
# reason_for_stop               object
# vehicle_make                  object
# vehicle_year                 float64
# raw_DriverRace                 int64
# ...

# %%
result.count()
# Out:
# date                         12748173
# time                         12737036
# location                     12624518
# beat                         12518024
# subject_age                      8316
# subject_race                 12747428
# subject_sex                  12747842
# department_id                12748173
# department_name              12748173
# type                         12748173
# violation                    12748163
# citation_issued              12748173
# warning_issued               12748173
# outcome                      12748172
# contraband_found               574565
# contraband_drugs               574519
# contraband_weapons             574556
# search_conducted             12731391
# search_person                12731391
# search_vehicle               12731256
# search_basis                   189648
# reason_for_stop              12748163
# vehicle_make                 12408765
# vehicle_year                 12735863
# raw_DriverRace               12748173
# ...

# %%
result.isnull().sum()
# Out:
# date                                0
# time                            11137
# location                       123655
# beat                           230149
# subject_age                  12739857
# subject_race                      745
# subject_sex                       331
# department_id                       0
# department_name                     0
# type                                0
# violation                          10
# citation_issued                     0
# warning_issued                      0
# outcome                             1
# contraband_found             12173608
# contraband_drugs             12173654
# contraband_weapons           12173617
# search_conducted                16782
# search_person                   16782
# search_vehicle                  16917
# search_basis                 12558525
# reason_for_stop                    10
# vehicle_make                   339408
# vehicle_year                    12310
# raw_DriverRace                      0
# ...

# %% [markdown]
# OK so far it´s similar
# But now we want only records with a contraband found.

# %%
contraband = result.loc[result['contraband_found'].isnull()==False]

# %%
contraband.head()
# Out:
#                       date      time location  beat  subject_age subject_race  \
# raw_row_number
# 36              2012-01-01  01:13:00    60653   724          NaN        black
# 37              2012-01-01  01:14:00    60707  2531          NaN        black
# 80              2012-01-01  07:33:00    60608   924          NaN     hispanic
# 89              2012-01-01  09:05:00    60609   914          NaN     hispanic
# 100             2012-01-01  10:30:00    60612  1532          NaN        black
#
#                subject_sex  department_id department_name       type  ...  \
# raw_row_number                                                        ...
# 36                    male        13194.0  CHICAGO POLICE  vehicular  ...
# 37                    male        13194.0  CHICAGO POLICE  vehicular  ...
# 80                    male        13194.0  CHICAGO POLICE  vehicular  ...
# 89                    male        13194.0  CHICAGO POLICE  vehicular  ...
# ...

# %%
contraband.isnull().sum()
# Out:
# date                              0
# time                            276
# location                       2603
# beat                          11671
# subject_age                  574560
# subject_race                      9
# subject_sex                       7
# department_id                     0
# department_name                   0
# type                              0
# violation                         0
# citation_issued                   0
# warning_issued                    0
# outcome                           0
# contraband_found                  0
# contraband_drugs                 46
# contraband_weapons                9
# search_conducted                  0
# search_person                     0
# search_vehicle                    0
# search_basis                 386191
# reason_for_stop                   0
# vehicle_make                  28841
# vehicle_year                    514
# raw_DriverRace                    0
# raw_ReasonForStop                 0
# ...

# %%
cleaned_contra = contraband.drop(['raw_DriverRace', 'raw_ReasonForStop', 'raw_TypeOfMovingViolation','raw_ResultOfStop'], axis = 'columns')

cleaned_contra.head()
# Out:
#                       date      time location  beat  subject_age subject_race  \
# raw_row_number
# 36              2012-01-01  01:13:00    60653   724          NaN        black
# 37              2012-01-01  01:14:00    60707  2531          NaN        black
# 80              2012-01-01  07:33:00    60608   924          NaN     hispanic
# 89              2012-01-01  09:05:00    60609   914          NaN     hispanic
# 100             2012-01-01  10:30:00    60612  1532          NaN        black
#
#                subject_sex  department_id department_name       type  ...  \
# raw_row_number                                                        ...
# 36                    male        13194.0  CHICAGO POLICE  vehicular  ...
# 37                    male        13194.0  CHICAGO POLICE  vehicular  ...
# 80                    male        13194.0  CHICAGO POLICE  vehicular  ...
# 89                    male        13194.0  CHICAGO POLICE  vehicular  ...
# ...

# %% [markdown]
# Well any prejudices?

# %%
result[result['subject_race'] == 'white'].search_conducted.value_counts(normalize=True)
# Out:
# search_conducted
# False    0.963831
# True     0.036169
# Name: proportion, dtype: float64

# %%
print('blacks')

result[result['subject_race'] == 'black'].search_conducted.value_counts(normalize=True)
# Out:
# blacks
# search_conducted
# False    0.931292
# True     0.068708
# Name: proportion, dtype: float64

# %%
result.groupby('subject_race').search_conducted.value_counts(normalize=True)
# Out:
# subject_race            search_conducted
# asian/pacific islander  False               0.984643
#                         True                0.015357
# black                   False               0.931292
#                         True                0.068708
# hispanic                False               0.937724
#                         True                0.062276
# other                   False               0.964709
#                         True                0.035291
# white                   False               0.963831
#                         True                0.036169
# Name: proportion, dtype: float64

# %%
output_contra = cleaned_contra.groupby('subject_race').contraband_found.value_counts(normalize=True)
output_contra
# Out:
# subject_race            contraband_found
# asian/pacific islander  False               0.813277
#                         True                0.186723
# black                   False               0.779934
#                         True                0.220066
# hispanic                False               0.845401
#                         True                0.154599
# other                   False               0.844551
#                         True                0.155449
# white                   False               0.782014
#                         True                0.217986
# Name: proportion, dtype: float64

# %% [markdown]
# Any other metrics?
# Age? Sex? Car age? (And how would you handle that one?)
# Visualize?
